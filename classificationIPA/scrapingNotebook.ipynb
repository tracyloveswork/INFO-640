# %%
import csv

# %%
with open('medium_ipa.csv', 'w') as csv_file:
    csv_writer = writer(csv_file)
    headers = ['Title', 'Link', 'Body']
    csv_writer.writerow(headers)

# %%
from csv import writer

# %%
with open('medium_ipa.csv', 'w') as csv_file:
    csv_writer = writer(csv_file)
    headers = ['Title', 'Link', 'Body']
    csv_writer.writerow(headers)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://medium.com/space10/how-voice-assistants-seemingly-came-from-nowhere-33747876b91f?source=search_post---------3"
html = urlopen(url)

# %%
url = "https://medium.com/space10/how-voice-assistants-seemingly-came-from-nowhere-33747876b91f"
html = urlopen(url)

# %%
url = 'https://medium.com/space10/how-voice-assistants-seemingly-came-from-nowhere-33747876b91f'

# %%
html = urlopen(url)

# %%
import urllib.request
import requests
import bs4
from bs4 import BeautifulSoup

# %%
from selenium import webdriver

# %%
# One of the artlicle responses
url = 'https://medium.com/space10/how-voice-assistants-seemingly-came-from-nowhere-33747876b91f'

# %%
driver = webdriver.Chrome('/Users/tracykubert/Google Drive/05 Pratt/07_2019_Fall/INFO-640-01 Data Analysis/03 Final Project/_code/chromedriver')
driver.get(url)

# %%
html = driver.execute_script("return document.documentElement.outerHTML")
driver.quit()

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get the article body
article = soup.select('article')

# %%
article_body = article.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-fca3e37696cb> in <module>
# ----> 1 article_body = article.get_text()
#
# AttributeError: 'list' object has no attribute 'get_text'

# %%
article_body = soup.select('article').get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-bbbfdb44a263> in <module>
# ----> 1 article_body = soup.select('article').get_text()
#
# AttributeError: 'list' object has no attribute 'get_text'

# %%
print(article)
# Out:
# [<article><section class="dt du dv dw ak dx bw n dy"></section><span class="r"></span><div><div class="dz u ea eb ec ed"></div><div class="dv dw dx fc"><div class="r h g f e"><aside class="rb dz t" style="width: 211.5px;"><div class="re rf dz rg cs ak"><h4 class="as de df au ax"><span class="bx rf cs cd cj">Top highlight</span></h4></div></aside></div></div><section class="ee ef eg eh ei"><div class="ej"><div class="n p"><div class="ek el em en eo ep ag eq ah er aj ak"><figure class="et eu ev ew ex ej ey ez paragraph-image"><div class="fa fb fc fd ak"><div class="dv dw es"><div class="fj r fc fk"><div class="fl r"><div class="fe ff dz t u fg ak cd fh fi"><img class="dz t u fg ak fm fn aq rh" height="1400" role="presentation" src="https://miro.medium.com/max/60/1*IVlyUX5p1mmVYaANb5XcIw.png?q=20" width="2500"/></div><img class="pg ra dz t u fg ak fp" height="1400" role="presentation" src="https://miro.medium.com/max/2500/1*IVlyUX5p1mmVYaANb5XcIw.png" width="2500"/><noscript><img class=
# ...

# %%
article_body = article.text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6837b1bc90cf> in <module>
# ----> 1 article_body = article.text()
#
# AttributeError: 'list' object has no attribute 'text'

# %%
text = soup.get_text()
print(soup.text)
# Out:
# !function(c,f){var t,o,i,e=[],r={passive:!0,capture:!0},n=new Date,a="pointerup",u="pointercancel";function p(n,e){t||(t=e,o=n,i=new Date,w(f),s())}function s(){0<=o&&o<i-n&&(e.forEach(function(n){n(o,t)}),e=[])}function l(n){if(n.cancelable){var e=(1e12<n.timeStamp?new Date:performance.now())-n.timeStamp;"pointerdown"==n.type?function(n,e){function t(){p(n,e),i()}function o(){i()}function i(){f(a,t,r),f(u,o,r)}c(a,t,r),c(u,o,r)}(e,n):p(e,n)}}function w(e){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(n){e(n,l,r)})}w(c),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){e.push(n),s()}}(addEventListener,removeEventListener)How voice assistants seemingly came from nowhere - SPACE10 - Medium(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# ...

# %%
article = soup.article

# %%
print(article.get_text())
# Out:
# Top highlightChatty devices, by Sandy van HeldenHow voice assistants seemingly came from nowhereOwen WilliamsFollowDec 7, 2016 · 9 min readIf you weren’t paying attention, you’re probably wondering why, all of a sudden, we’re conversing with devices like we can with humans. Instead of clicking on buttons on your screen, in 2016 you’re able to simply talk out loud in a room, and have a speaker with a voice assistant inside understand exactly your intent and what you said.This article is a part of the “Do you speak human?” lab — enabled by SPACE10 to explore conversational interfaces and AI. Make sure you dive into the entire publication.Over the last few years, inventions such as Apple’s Siri, Google Assistant and Microsoft Cortana have flipped the way we think of interacting using voice with our devices on its head.Siri, which launched in 2011 along with the iPhone 4S, was incredible at the time: an assistant that could understand you, and even crack jokes — how could a computer be s
# ...

# %%
# Get the article title
article_title = soup.title
print(article_title)
# Out:
# <title>How voice assistants seemingly came from nowhere - SPACE10 - Medium</title>

# %%
article_title = soup.title.get_text()

# %%
print(article_title)
# Out:
# How voice assistants seemingly came from nowhere - SPACE10 - Medium

# %%
article_date = soup.date

# %%
print(article_date)
# Out:
# None

# %%
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
article_date = soup.find_all('a', attrs={"class": "bo bp bq br bs bt bu bv bw bx hq ca cb cc cd"})

# %%
print(article_date)
# Out:
# []

# %%
article_date = soup.find_all('article > span > span > a', attrs={'rel': 'noopener'})

# %%
print(article_date)
# Out:
# []

# %%
article_date = soup.find_all('article > a', attrs={'rel': 'noopener'})

# %%
print(article_date)
# Out:
# []

# %%
article_date = soup.find_all('a', class_="bo bp bq br bs bt bu bv bw bx hq ca cb cc cd")

# %%
print(article_date)
# Out:
# []

# %%
article_date = soup.find_all('a', attrs={'rel': 'noopener'})

# %%
print(article_date)
# Out:
# [<a aria-label="Homepage" href="/?source=post_page-----33747876b91f----------------------" rel="noopener"><svg class="q" height="35" viewbox="5 5 35 35" width="35"><path d="M5 40V5h35v35H5zm8.56-12.63c0 .56-.03.69-.32 1.03L10.8 31.4v.4h6.97v-.4L15.3 28.4c-.29-.34-.34-.5-.34-1.03v-8.95l6.13 13.36h.71l5.26-13.36v10.64c0 .3 0 .35-.19.53l-1.85 1.8v.4h9.2v-.4l-1.83-1.8c-.18-.18-.2-.24-.2-.53V15.94c0-.3.02-.35.2-.53l1.82-1.8v-.4h-6.47l-4.62 11.55-5.2-11.54h-6.8v.4l2.15 2.63c.24.3.29.37.29.77v10.35z"></path></svg></a>, <a class="az ba bb bc bd be bf bg bh bi bj bk bl bm bn bo" href="https://medium.com/m/signin?operation=login&amp;redirect=https%3A%2F%2Fmedium.com%2Fspace10%2Fhow-voice-assistants-seemingly-came-from-nowhere-33747876b91f&amp;source=post_page-----33747876b91f---------------------nav_reg-" rel="noopener">Sign in</a>, <a href="/space10?source=post_page-----33747876b91f----------------------" rel="noopener"><span class="as cf cg ch cd ci cj ck cl cm cn">SPACE10</span></a>, <a cla
# ...

# %%
article_date = soup.find_all('a', attrs={'rel': 'noopener'}).get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-b2aa055f26c9> in <module>
# ----> 1 article_date = soup.find_all('a', attrs={'rel': 'noopener'}).get_text()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1600     def __getattr__(self, key):
#    1601         raise AttributeError(
# -> 1602             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1603         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
article_date = soup.find_all('a', attrs={'rel': 'noopener'})

# %%
article_date.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-869f8379e06a> in <module>
# ----> 1 article_date.get_text()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1600     def __getattr__(self, key):
#    1601         raise AttributeError(
# -> 1602             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1603         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
article_date = soup.select('article > span > span > div > a', attrs={'rel': 'noopener'})

# %%
print(article_date)
# Out:
# []

# %%
article_date = soup.select('article', attrs={'rel': 'noopener'})

# %%
print(article_date)
# Out:
# []

# %%
article_date = soup.select('article span div a', attrs={'rel': 'noopener'})

# %%
print(article_date)
# Out:
# [<a class="dj dk bb bc bd be bf bg bh bi gz bl bm ha hb" href="/@ow?source=post_page-----33747876b91f----------------------" rel="noopener">Owen Williams</a>, <a class="dj dk bb bc bd be bf bg bh bi gz bl bm ha hb" href="/space10/how-voice-assistants-seemingly-came-from-nowhere-33747876b91f?source=post_page-----33747876b91f----------------------" rel="noopener">Dec 7, 2016</a>]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-f0815551ed31> in <module>
# ----> 1 print(article_date.get_text())
#
# AttributeError: 'list' object has no attribute 'get_text'

# %%
len(article_date)
# Out:
# 2

# %%
article_date.extract()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-2e91df15e7f3> in <module>
# ----> 1 article_date.extract()
#
# AttributeError: 'list' object has no attribute 'extract'

# %%
article_meta = soup.select('article span div a', attrs={'rel': 'noopener'}).get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-3537366c0827> in <module>
# ----> 1 article_meta = soup.select('article span div a', attrs={'rel': 'noopener'}).get_text()
#
# AttributeError: 'list' object has no attribute 'get_text'

# %%
article_meta = soup.select('article span div a', attrs={'rel': 'noopener'})

# %%
article_body = soup.article.get_text()

# %%
print(article_body)
# Out:
# Top highlightChatty devices, by Sandy van HeldenHow voice assistants seemingly came from nowhereOwen WilliamsFollowDec 7, 2016 · 9 min readIf you weren’t paying attention, you’re probably wondering why, all of a sudden, we’re conversing with devices like we can with humans. Instead of clicking on buttons on your screen, in 2016 you’re able to simply talk out loud in a room, and have a speaker with a voice assistant inside understand exactly your intent and what you said.This article is a part of the “Do you speak human?” lab — enabled by SPACE10 to explore conversational interfaces and AI. Make sure you dive into the entire publication.Over the last few years, inventions such as Apple’s Siri, Google Assistant and Microsoft Cortana have flipped the way we think of interacting using voice with our devices on its head.Siri, which launched in 2011 along with the iPhone 4S, was incredible at the time: an assistant that could understand you, and even crack jokes — how could a computer be s
# ...

# %%
article_date = article_meta[1]

# %%
print(article_date)
# Out:
# <a class="dj dk bb bc bd be bf bg bh bi gz bl bm ha hb" href="/space10/how-voice-assistants-seemingly-came-from-nowhere-33747876b91f?source=post_page-----33747876b91f----------------------" rel="noopener">Dec 7, 2016</a>

# %%
article_meta_text = BeautifulSoup(article_meta, "lxml").get_text()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-05a00c05b950> in <module>
# ----> 1 article_meta_text = BeautifulSoup(article_meta, "lxml").get_text()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     308          self.contains_replacement_characters) in (
#     309              self.builder.prepare_markup(
# --> 310                  markup, from_encoding, exclude_encodings=exclude_encodings)):
#     311             self.reset()
#     312             try:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/builder/_lxml.py in prepare_markup(self, markup, user_specified_encoding, exclude_encodings, document_declared_encoding)
# ...

# %%
article_author = BeautifulSoup(article_meta[0]).get_text()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-e919e65b6263> in <module>
# ----> 1 article_author = BeautifulSoup(article_meta[0]).get_text()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     272
#     273         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 274             markup = markup.read()
#     275         elif len(markup) <= 256 and (
#     276                 (isinstance(markup, bytes) and not b'<' in markup)
#
# TypeError: 'NoneType' object is not callable

# %%
article_author = BeautifulSoup(article_meta[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-772cedfa4de0> in <module>
# ----> 1 article_author = BeautifulSoup(article_meta[0])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     272
#     273         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 274             markup = markup.read()
#     275         elif len(markup) <= 256 and (
#     276                 (isinstance(markup, bytes) and not b'<' in markup)
#
# TypeError: 'NoneType' object is not callable

# %%
article_author = article_meta[0]

# %%
print(article_author)
# Out:
# <a class="dj dk bb bc bd be bf bg bh bi gz bl bm ha hb" href="/@ow?source=post_page-----33747876b91f----------------------" rel="noopener">Owen Williams</a>

# %%
article_author_text = BeautifulSoup(article_author)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-7767ae9f4114> in <module>
# ----> 1 article_author_text = BeautifulSoup(article_author)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     272
#     273         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 274             markup = markup.read()
#     275         elif len(markup) <= 256 and (
#     276                 (isinstance(markup, bytes) and not b'<' in markup)
#
# TypeError: 'NoneType' object is not callable

# %%
article_author_text = BeautifulSoup(article_author,"html.parser")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-2c2ec8e3ffdd> in <module>
# ----> 1 article_author_text = BeautifulSoup(article_author,"html.parser")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     272
#     273         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 274             markup = markup.read()
#     275         elif len(markup) <= 256 and (
#     276                 (isinstance(markup, bytes) and not b'<' in markup)
#
# TypeError: 'NoneType' object is not callable

# %%
article_author = str(article_meta[0])

# %%
article_author_text = BeautifulSoup(article_author,"html.parser")

# %%
article_author_text.get_text()
# Out:
# 'Owen Williams'

# %%
article_author_text = BeautifulSoup(article_author,"html.parser").get_text()

# %%
print(article_author_text)
# Out:
# Owen Williams

# %%
article_date = str(article_meta[1])

# %%
article_date_text = BeautifulSoup(article_date,"html.parser").get_text()

# %%
print(article_date_text)
# Out:
# Dec 7, 2016

# %%
print(article_body)
# Out:
# Top highlightChatty devices, by Sandy van HeldenHow voice assistants seemingly came from nowhereOwen WilliamsFollowDec 7, 2016 · 9 min readIf you weren’t paying attention, you’re probably wondering why, all of a sudden, we’re conversing with devices like we can with humans. Instead of clicking on buttons on your screen, in 2016 you’re able to simply talk out loud in a room, and have a speaker with a voice assistant inside understand exactly your intent and what you said.This article is a part of the “Do you speak human?” lab — enabled by SPACE10 to explore conversational interfaces and AI. Make sure you dive into the entire publication.Over the last few years, inventions such as Apple’s Siri, Google Assistant and Microsoft Cortana have flipped the way we think of interacting using voice with our devices on its head.Siri, which launched in 2011 along with the iPhone 4S, was incredible at the time: an assistant that could understand you, and even crack jokes — how could a computer be s
# ...

# %%
from csv import writer

# %%
with open('medium_ipa.csv', 'w') as csv_file:
    csv_writer = writer(csv_file)
    headers = ['Title', 'Link', 'Date', 'Author','Body']
    csv_writer.writerow(headers)

# %%
page_url = 'https://onezero.medium.com/voice-forward-phones-google-assistant-and-the-next-billion-users-119a9868837b?source=search_post---------5'

# %%
driver.get(page_url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
page_url = 'https://onezero.medium.com/voice-forward-phones-google-assistant-and-the-next-billion-users-119a9868837b'

# %%
driver.get(page_url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...
